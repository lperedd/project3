# %%
import os
import pandas as pd
import snowflake.connector

def load_csv_to_snowflake(csv_file_path, connection):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Get the table name from the CSV file name (assuming the file name is the table name)
    table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

    # Create a Snowflake table using the DataFrame
    with connection.cursor() as cursor:
        cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} (LIKE TEMPLATE_TABLE)")
        connection.commit()

        # Write data from the DataFrame to the Snowflake table
        df.to_sql(table_name, connection, schema='operations', if_exists='replace', index=False)

def main():
    # Snowflake connection parameters
    snowflake_params = {
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'account': 'pajfrmr-fd96872',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations',


    }

    # Establish a connection to Snowflake
    with snowflake.connector.connect(**snowflake_params) as connection:
        # Local folder containing CSV files
        folder_path = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

        # Iterate through all files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.csv'):
                file_path = os.path.join(folder_path, file_name)
                load_csv_to_snowflake(file_path, connection)
                print(f"Data from {file_name} loaded into Snowflake.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[8], line 46
#      43                 print(f"Data from {file_name} loaded into Snowflake.")
#      45 if __name__ == "__main__":
# ---> 46     main()
#
# Cell In[8], line 42, in main()
#      40 if file_name.endswith('.csv'):
#      41     file_path = os.path.join(folder_path, file_name)
# ---> 42     load_csv_to_snowflake(file_path, connection)
#      43     print(f"Data from {file_name} loaded into Snowflake.")
#
# Cell In[8], line 14, in load_csv_to_snowflake(csv_file_path, connection)
#      12 # Create a Snowflake table using the DataFrame
#      13 with connection.cursor() as cursor:
# ---> 14     cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} (LIKE TEMPLATE_TABLE)")
#      15     connection.commit()
#      17     # Write data from the DataFrame to the Snowflake table
#
# ...

# %%
import snowflake.connector

# Replace these values with your Snowflake account details
account = 'pajfrmr-fd96872'
user = 'ANALYTICS_USER'
password = 'Infosum8-8'
warehouse = 'compute_wh'
database = 'ACME_ECOMMERCE'
schema = 'operations'


# Establishing a connection
conn = snowflake.connector.connect(
    user=user,
    password=password,
    account=account,
    warehouse=warehouse,
    database=database,
    schema=schema
)

# Creating a cursor object
cursor = conn.cursor()

try:
    # Execute a simple query
    cursor.execute("SELECT CURRENT_DATE()")

    # Fetch the result
    result = cursor.fetchone()
    print("Current date from Snowflake:", result[0])

finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Current date from Snowflake: 2024-03-03

# %%
import os

folder_path = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

# Check if the folder path exists
if os.path.exists(folder_path) and os.path.isdir(folder_path):
    csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
    
    if csv_files:
        print("CSV files found in the folder:")
        for csv_file in csv_files:
            print(os.path.join(folder_path, csv_file))
    else:
        print("No CSV files found in the folder.")
else:
    print("The specified folder path does not exist.")
# Out:
# CSV files found in the folder:
# C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data\factories.csv

# %%
import os
import pandas as pd
import snowflake.connector

def load_csv_to_snowflake(csv_file_path, connection):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Get the table name from the CSV file name (assuming the file name is the table name)
    table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

    # Create a Snowflake table with the specified structure
    with connection.cursor() as cursor:
        cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} "
                       "(factory_id INT, location_id INT, size VARCHAR, number_of_employees INT, in_use BOOLEAN)")
        connection.commit()

        # Write data from the DataFrame to the Snowflake table
        df.to_sql(table_name, connection, schema='operations', if_exists='replace', index=False)


def main():
    # Snowflake connection parameters
    snowflake_params = {
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'account': 'pajfrmr-fd96872',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations',
    }

    # Establish a connection to Snowflake
    with snowflake.connector.connect(**snowflake_params) as connection:
        try:
              # Add the 'ADMINISTRADOR' role to the session
            cursor.execute("USE ROLE ACCOUNTADMIN")
            # Set the current database and schema
            connection.cursor().execute(f"USE {snowflake_params['database']}.{snowflake_params['schema']}")
            print(f"Connected to Snowflake. Using database: {snowflake_params['database']}, schema: {snowflake_params['schema']}")

            # Local folder containing CSV files
            folder_path = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

            # Iterate through all files in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.csv'):
                    file_path = os.path.join(folder_path, file_name)
                    load_csv_to_snowflake(file_path, connection)
                    print(f"Data from {file_name} loaded into Snowflake.")

        except Exception as e:
            print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Error: 252006: Cursor is closed in execute.

# %%
import os
import pandas as pd
import snowflake.connector

def load_csv_to_snowflake(csv_file_path, connection):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Get the table name from the CSV file name (assuming the file name is the table name)
    table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

    # Create a Snowflake table with the specified structure
    with connection.cursor() as cursor:
        cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} "
                       "(factory_id INT, location_id INT, size VARCHAR, number_of_employees INT, in_use BOOLEAN)")
        connection.commit()

        # Write data from the DataFrame to the Snowflake table
        df.to_sql(table_name, connection, schema='operations', if_exists='replace', index=False)

def main():
    # Snowflake connection parameters
    snowflake_params = {
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'account': 'pajfrmr-fd96872',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations',
    }

    # Establish a connection to Snowflake
    with snowflake.connector.connect(**snowflake_params) as connection:
        try:
            # Print the SQL statement before executing
            use_statement = f"USE {snowflake_params['database']}.{snowflake_params['schema']}"
            print(f"Executing SQL statement: {use_statement}")

            # Set the current database and schema
            connection.cursor().execute(use_statement)
            print(f"Connected to Snowflake. Using database: {snowflake_params['database']}, schema: {snowflake_params['schema']}")

            # Rest of your code...
        except Exception as e:
            print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Executing SQL statement: USE ACME_ECOMMERCE.operations
# Error: 002043 (02000): SQL compilation error:
# Object does not exist, or operation cannot be performed.

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
        'account': 'pajfrmr-fd96872',
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'warehouse': 'compute_wh',
        'database': 'acme_ecommerce',
        'schema': 'operations',

}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Add the 'ADMINISTRADOR' role to the session
    cursor.execute("USE ROLE ACCOUNTADMIN")
    # Create 'operations' schema if it doesn't exist
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a new table in the 'operations' schema
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {snowflake_config['database']}.operations.factories ("
                   "column1 VARCHAR, "
                   "column2 INT, "
                   "column3 FLOAT"
                   # Add more columns based on your dataset structure
                   ")")

    # Copy data from CSV file to the new table
    cursor.execute(f"COPY INTO {snowflake_config['database']}.operations.factories "
                   f"FROM @%operations.factories/data/pipeline_data/factories.csv "
                   "FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')")

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 002003 (02000): SQL compilation error:
# Schema 'ACME_ECOMMERCE."%OPERATIONS"' does not exist or not authorized.

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Create 'operations' schema if it doesn't exist
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a new table in the 'operations' schema
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {snowflake_config['database']}.operations.factories ("
                   "column1 VARCHAR, "
                   "column2 INT, "
                   "column3 FLOAT"
                   # Add more columns based on your dataset structure
                   ")")

    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO {snowflake_config['database']}.operations.factories " \
               f"FROM @%operations.factories/data/pipeline_data/factories.csv " \
               "FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"

    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 002003 (02000): SQL compilation error:
# Database 'ACME_ECOMMERCE' does not exist or not authorized.
# Failed SQL Statement:

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Add the 'ADMINISTRADOR' role to the session
    cursor.execute("USE ROLE ACCOUNTADMIN")

    # Create 'operations' schema if it doesn't exist
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a new table in the 'operations' schema
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {snowflake_config['database']}.operations.factories ("
                   "column1 VARCHAR, "
                   "column2 INT, "
                   "column3 FLOAT"
                   # Add more columns based on your dataset structure
                   ")")

    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO {snowflake_config['database']}.operations.factories " \
               f"FROM @%operations.factories/data/pipeline_data/factories.csv " \
               "FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"

    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 002003 (02000): SQL compilation error:
# Schema 'ACME_ECOMMERCE."%OPERATIONS"' does not exist or not authorized.
# Failed SQL Statement: COPY INTO ACME_ECOMMERCE.operations.factories FROM @%operations.factories/data/pipeline_data/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='"')

# %%
import os
import pandas as pd
import snowflake.connector

def create_snowflake_table(connection, table_name):
    try:
        with connection.cursor() as cursor:
            cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} "
                           "(factory_id INT, location_id INT, size VARCHAR, number_of_employees INT, in_use BOOLEAN)")
            connection.commit()
    except Exception as e:
        print(f"Error creating table {table_name}: {e}")

def write_data_to_snowflake(df, table_name, connection):
    try:
        df.to_sql(table_name, connection, schema='operations', if_exists='replace', index=False)
        print(f"Data loaded into Snowflake table: {table_name}")
    except Exception as e:
        print(f"Error writing data to Snowflake table {table_name}: {e}")

def load_csv_to_snowflake(csv_file_path, connection):
    try:
        # Read CSV file into a pandas DataFrame
        df = pd.read_csv(csv_file_path)

        # Get the table name from the CSV file name
        table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

        # Create a Snowflake table with the specified structure
        create_snowflake_table(connection, table_name)

        # Write data from the DataFrame to the Snowflake table
        write_data_to_snowflake(df, table_name, connection)

    except Exception as e:
        print(f"Error loading CSV to Snowflake: {e}")

def main():
    # Snowflake connection parameters
    snowflake_params = {
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'account': 'pajfrmr-fd96872',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations',
    }

    try:
        # Establish a connection to Snowflake
        with snowflake.connector.connect(**snowflake_params) as connection:
            # Add the 'ADMINISTRADOR' role to the session
            connection.cursor().execute("USE ROLE ACCOUNTADMIN")

            # Set the current database and schema
            connection.cursor().execute(f"USE {snowflake_params['database']}.{snowflake_params['schema']}")
            print(f"Connected to Snowflake. Using database: {snowflake_params['database']}, schema: {snowflake_params['schema']}")

            # Local folder containing CSV files
            folder_path = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

            # Iterate through all files in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.csv'):
                    file_path = os.path.join(folder_path, file_name)
                    load_csv_to_snowflake(file_path, connection)

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Connected to Snowflake. Using database: ACME_ECOMMERCE, schema: operations
# C:\Users\luism\AppData\Local\Temp\ipykernel_19460\1707071256.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql(table_name, connection, schema='operations', if_exists='replace', index=False)
# Error writing data to Snowflake table factories: Execution failed on sql '
#         SELECT
#             name
#         FROM
#             sqlite_master
#         WHERE
#             type IN ('table', 'view')
#             AND name=?;
#         ': not all arguments converted during string formatting

# %%
import os
import pandas as pd
import snowflake.connector
from sqlalchemy import create_engine

def create_snowflake_table(connection, table_name):
    try:
        with connection.cursor() as cursor:
            cursor.execute(f"CREATE TABLE IF NOT EXISTS operations.{table_name} "
                           "(factory_id INT, location_id INT, size VARCHAR, number_of_employees INT, in_use BOOLEAN)")
            connection.commit()
    except Exception as e:
        print(f"Error creating table {table_name}: {e}")


def write_data_to_snowflake(df, table_name, connection_params):
    try:
        # Create a Snowflake connection string for SQLAlchemy
        snowflake_engine = create_engine(f'snowflake://{connection_params["user"]}:{connection_params["password"]}@{connection_params["account"]}/{connection_params["warehouse"]}/{connection_params["database"]}?schema={connection_params["schema"]}')

        # Write data from the DataFrame to the Snowflake table using the SQLAlchemy engine
        df.to_sql(table_name, snowflake_engine, if_exists='replace', index=False, schema='operations')

        print(f"Data loaded into Snowflake table: {table_name}")
    except Exception as e:
        print(f"Error writing data to Snowflake table {table_name}: {e}")

def load_csv_to_snowflake(csv_file_path, connection_params):
    try:
        # Read CSV file into a pandas DataFrame
        df = pd.read_csv(csv_file_path)

        # Get the table name from the CSV file name
        table_name = os.path.splitext(os.path.basename(csv_file_path))[0]

        # Create a Snowflake table with the specified structure
        create_snowflake_table(connection_params, table_name)

        # Write data from the DataFrame to the Snowflake table
        write_data_to_snowflake(df, table_name, connection_params)

    except Exception as e:
        print(f"Error loading CSV to Snowflake: {e}")

def main():
    # Snowflake connection parameters
    snowflake_params = {
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'account': 'pajfrmr-fd96872',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations',
    }

    try:
        # Establish a connection to Snowflake
        with snowflake.connector.connect(**snowflake_params) as connection:
            # Add the 'ADMINISTRADOR' role to the session
            connection.cursor().execute("USE ROLE ACCOUNTADMIN")

            # Set the current database and schema
            connection.cursor().execute(f"USE {snowflake_params['database']}.{snowflake_params['schema']}")
            print(f"Connected to Snowflake. Using database: {snowflake_params['database']}, schema: {snowflake_params['schema']}")

            # Local folder containing CSV files
            folder_path = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

            # Iterate through all files in the folder
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.csv'):
                    file_path = os.path.join(folder_path, file_name)
                    load_csv_to_snowflake(file_path, snowflake_params)

    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Connected to Snowflake. Using database: ACME_ECOMMERCE, schema: operations
# Error creating table factories: 'dict' object has no attribute 'cursor'
# Error writing data to Snowflake table factories: Can't load plugin: sqlalchemy.dialects:snowflake

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Create 'operations' schema if it doesn't exist
    cursor.execute(f"USE ROLE ACCOUNTADMIN")
    cursor.execute(f"DROP TABLE IF EXISTS operations.factories")
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a new table in the 'operations' schema
    cursor.execute(f"CREATE TABLE operations.factories (
    factory_id INT,
    location_id INT,
    size VARCHAR,
    number_of_employees INT,
    in_use BOOLEAN
)")

    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO {snowflake_config['database']}.operations.factories " \
               f"FROM @%operations.factories/data/pipeline_data/factories.csv " \
               "FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"

    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"

dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Create 'operations' schema if it doesn't exist
    cursor.execute("USE ROLE ACCOUNTADMIN")
    cursor.execute(f"CREATE DATABASE IF NOT EXISTS {snowflake_config['database']}")
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a new table in the 'operations' schema
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {snowflake_config['database']}.operations.factories ("
                   f"factory_id INT,"
                   f"location_id INT,"
                   f"size VARCHAR,"
                   f"number_of_employees INT,"
                   f"in_use BOOLEAN"
                   f")")

    # Build the COPY INTO SQL statement
    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO ACME_ECOMMERCE.operations.factories " \
           f"FROM '{dataset_filepath}' " \
           "FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"



    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 001011 (42601): SQL compilation error:
# invalid URL prefix found in: 'C:UsersluismDesktopdatagithub_repossliidedatapipeline_dataactories.csv'
# Failed SQL Statement: COPY INTO ACME_ECOMMERCE.operations.factories FROM 'C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data\factories.csv' FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='"')

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"
dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Create 'operations' schema if it doesn't exist
    cursor.execute("USE ROLE ACCOUNTADMIN")
    cursor.execute(f"CREATE DATABASE IF NOT EXISTS {snowflake_config['database']}")
    cursor.execute(f"CREATE SCHEMA IF NOT EXISTS {snowflake_config['database']}.operations")

    # Create a named internal stage
    stage_name = 'your_stage_name'  # Replace with a suitable name
    cursor.execute(f"CREATE STAGE IF NOT EXISTS {snowflake_config['database']}.operations.{stage_name} "
                   f"FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')")

    # Build the PUT SQL statement to copy data to the stage
    put_sql = f"PUT file://{dataset_filepath} @.{stage_name}"

    # Execute the PUT SQL statement
    cursor.execute(put_sql)

    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO {snowflake_config['database']}.operations.factories " \
           f"FROM @{stage_name}/factories.csv " \
           f"FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"

    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 002003 (02000): SQL compilation error:
# Schema 'ACME_ECOMMERCE.""' does not exist or not authorized.
# Failed SQL Statement: COPY INTO ACME_ECOMMERCE.operations.factories FROM 'C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data\factories.csv' FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='"')

# %%
import snowflake.connector
import os

# Snowflake connection parameters
snowflake_config = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations',
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"
dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(
    user=snowflake_config['user'],
    password=snowflake_config['password'],
    account=snowflake_config['account'],
    warehouse=snowflake_config['warehouse'],
    database=snowflake_config['database'],
    schema=snowflake_config['schema']
)

# Create a cursor object
cursor = conn.cursor()

try:
    # Set the current database and schema
    cursor.execute(f"USE DATABASE {snowflake_config['database']}")
    cursor.execute(f"USE SCHEMA {snowflake_config['schema']}")

    # Create a named internal stage
    stage_name = 'your_stage_name'  # Replace with a suitable name
    cursor.execute(f"CREATE STAGE IF NOT EXISTS {snowflake_config['database']}.operations.{stage_name} "
                   f"FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')")

    # Build the PUT SQL statement to copy data to the stage
    put_sql = f"PUT file://{dataset_filepath} @.{stage_name}"

    # Execute the PUT SQL statement
    cursor.execute(put_sql)

    # Build the COPY INTO SQL statement
    copy_sql = f"COPY INTO factories " \
               f"FROM @{stage_name}/factories.csv " \
               f"FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='\"')"

    # Execute the COPY INTO SQL statement
    cursor.execute(copy_sql)

    # Commit the changes
    conn.commit()

    print("Data loaded successfully.")
except Exception as e:
    print(f"Error: {e}")
    print(f"Failed SQL Statement: {copy_sql}")
finally:
    # Close the cursor and connection
    cursor.close()
    conn.close()
# Out:
# Error: 002043 (02000): SQL compilation error:
# Object does not exist, or operation cannot be performed.
# Failed SQL Statement: COPY INTO ACME_ECOMMERCE.operations.factories FROM 'C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data\factories.csv' FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY='"')

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    account='pajfrmr-fd96872',
    user='ANALYTICS_USER',
    password='Infosum8-8',
    warehouse='compute_wh',
    database='ACME_ECOMMERCE',
    schema='operations'
)

cur = conn.cursor()

try:
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute('SELECT * FROM ACME_ECOMMERCE.OPERATIONS.FACTORIES')
    one_row = cur.fetchone()
    print(one_row)
finally:
    cur.close()
    conn.close()
# Out:
# (1, 1, 'ss', 3, True)

# %%
import os
import snowflake.connector

# Snowflake connection parameters
conn_params = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations'
}

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data\factories.csv"
dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Snowflake connection
conn = snowflake.connector.connect(**conn_params)
cur = conn.cursor()

try:
    # Use the appropriate Snowflake COPY INTO command
    copy_command = f"COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{dataset_filepath}' FILE_FORMAT = (FORMAT_NAME = 'CSV')"
    
    # Execute the COPY command
    cur.execute(copy_command)
    
    # Commit the transaction
    conn.commit()
    
    # Print success message
    print(f"Data from {dataset_filename} copied into the Snowflake table successfully.")
    
finally:
    cur.close()
    conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[41], line 28
#      25 copy_command = f"COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{dataset_filepath}' FILE_FORMAT = (FORMAT_NAME = 'CSV')"
#      27 # Execute the COPY command
# ---> 28 cur.execute(copy_command)
#      30 # Commit the transaction
#      31 conn.commit()
#
# File c:\Users\luism\Desktop\data\github_repos\sliide\venv\lib\site-packages\snowflake\connector\cursor.py:1132, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
# ...

# %%
import snowflake.connector
import os

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"
dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

conn = snowflake.connector.connect(
    account='pajfrmr-fd96872',
    user='ANALYTICS_USER',
    password='Infosum8-8',
    warehouse='compute_wh',
    database='ACME_ECOMMERCE',
    schema='operations'
)

cur = conn.cursor()

try:
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute('SELECT * FROM ACME_ECOMMERCE.OPERATIONS.FACTORIES')
    one_row = cur.fetchone()
    print(one_row)
    cur.execute ("COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{dataset_filepath}' FILE_FORMAT = (FORMAT_NAME = 'CSV')")
finally:
    cur.close()
    conn.close()
# Out:
# (1, 1, 'ss', 3, True)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[43], line 25
#      23     one_row = cur.fetchone()
#      24     print(one_row)
# ---> 25     cur.execute ("COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{dataset_filepath}' FILE_FORMAT = (FORMAT_NAME = 'CSV')")
#      26 finally:
#      27     cur.close()
#
# ...

# %%
import snowflake.connector
import os

# Filepath to the dataset
data_folder = r"C:\Users\luism\Desktop\data\github_repos\sliide\data\pipeline_data"
dataset_filename = 'factories.csv'
dataset_filepath = os.path.join(data_folder, dataset_filename)

# Set up Snowflake stage
stage_name = 'OPERATIONS_STAGE'
stage_url = f"@%{stage_name}/{dataset_filename}"

conn = snowflake.connector.connect(
    account='pajfrmr-fd96872',
    user='ANALYTICS_USER',
    password='Infosum8-8',
    warehouse='compute_wh',
    database='ACME_ECOMMERCE',
    schema='operations'
)

cur = conn.cursor()

try:
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute('SELECT * FROM ACME_ECOMMERCE.OPERATIONS.FACTORIES')
    one_row = cur.fetchone()
    print(one_row)

    # Use Snowflake stage URL in the COPY command
    copy_query = f"COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{stage_url}' FILE_FORMAT = (FORMAT_NAME = 'CSV')"
    cur.execute(copy_query)

finally:
    cur.close()
    conn.close()
# Out:
# (1, 1, 'ss', 3, True)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[48], line 32
#      30     # Use Snowflake stage URL in the COPY command
#      31     copy_query = f"COPY INTO ACME_ECOMMERCE.OPERATIONS.FACTORIES FROM '{stage_url}' FILE_FORMAT = (FORMAT_NAME = 'CSV')"
# ---> 32     cur.execute(copy_query)
#      34 finally:
#      35     cur.close()
#
# ...

# %%
import snowflake.connector

# Snowflake connection parameters
snowflake_params = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations'
}

# Snowflake stage information
stage_name = 'MY_LOCAL_STAGE'
stage_location = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\'

# CSV file information
csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
table_name = 'FACTORIES'

# Snowflake connection
conn = snowflake.connector.connect(**snowflake_params)
cur = conn.cursor()

try:
    # Create the Snowflake stage
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute(f'CREATE OR REPLACE STAGE {stage_name} URL = \'{stage_location}\'')

    # Put the CSV file into the stage
    cur.execute(f'PUT file://{csv_file_path} @{stage_name}')

    # Copy data from the stage to the table
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cur.execute(copy_command)

    # Verify the data is loaded
    cur.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cur.fetchone()
    print(one_row)
finally:
    # Drop the stage
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute(f'DROP STAGE IF EXISTS {stage_name}')

    # Close cursor and connection
    cur.close()
    conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[52], line 28
#      25 try:
#      26     # Create the Snowflake stage
#      27     cur.execute('USE ROLE ACCOUNTADMIN')
# ---> 28     cur.execute(f'CREATE OR REPLACE STAGE {stage_name} URL = \'{stage_location}\'')
#      30     # Put the CSV file into the stage
#      31     cur.execute(f'PUT file://{csv_file_path} @{stage_name}')
#
# ...

# %%
import snowflake.connector

# Snowflake connection parameters
snowflake_params = {
    'account': 'pajfrmr-fd96872',
    'user': 'ANALYTICS_USER',
    'password': 'Infosum8-8',
    'warehouse': 'compute_wh',
    'database': 'ACME_ECOMMERCE',
    'schema': 'operations'
}

# Snowflake stage information
stage_name = 'MY_LOCAL_STAGE'
stage_location = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\'

# CSV file information
csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
table_name = 'FACTORIES'

# Snowflake connection
conn = snowflake.connector.connect(**snowflake_params)
cur = conn.cursor()

try:
    # Create the Snowflake stage
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute(f'CREATE OR REPLACE STAGE {stage_name}')

    # Put the CSV file into the stage
    cur.execute(f"PUT file://{csv_file_path} @{stage_name}")

    # Copy data from the stage to the table
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cur.execute(copy_command)

    # Verify the data is loaded
    cur.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cur.fetchone()
    print(one_row)
finally:
    # Drop the stage
   # cur.execute(f'DROP STAGE IF EXISTS {stage_name}')

    # Close cursor and connection
    cur.close()
    conn.close()
# Out:
# (1, 1, 'ss', 3, True)

# %%
import snowflake.connector

def connect_to_snowflake(params):
    return snowflake.connector.connect(**params)

def create_snowflake_stage(cursor, stage_name):
    cursor.execute('USE ROLE ACCOUNTADMIN')
    cursor.execute(f'CREATE OR REPLACE STAGE {stage_name}')

def put_csv_file_to_stage(cursor, csv_file_path, stage_name):
    cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

def copy_data_to_table(cursor, table_name, stage_name):
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cursor.execute(copy_command)

def verify_data_loaded(cursor, table_name):
    cursor.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cursor.fetchone()
    print(one_row)

def drop_snowflake_stage(cursor, stage_name):
    cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

def close_connection(cursor, connection):
    cursor.close()
    connection.close()

if __name__ == "__main__":
    # Snowflake connection parameters
    snowflake_params = {
        'account': 'pajfrmr-fd96872',
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations'
    }

    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Snowflake connection
    conn = connect_to_snowflake(snowflake_params)
    cur = conn.cursor()

    try:
        create_snowflake_stage(cur, stage_name)
        put_csv_file_to_stage(cur, csv_file_path, stage_name)
        copy_data_to_table(cur, table_name, stage_name)
        verify_data_loaded(cur, table_name)
    finally:
        # Drop the stage
        # drop_snowflake_stage(cur, stage_name)

        # Close cursor and connection
        close_connection(cur, conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[57], line 54
#      52     create_snowflake_stage(cur, stage_name)
#      53     put_csv_file_to_stage(cur, csv_file_path, stage_name)
# ---> 54     copy_data_to_table(cur, table_name, stage_name)
#      55     verify_data_loaded(cur, table_name)
#      56 finally:
#      57     # Drop the stage
#      58     # drop_snowflake_stage(cur, stage_name)
#      59
#      60     # Close cursor and connection
#
# Cell In[57], line 15, in copy_data_to_table(cursor, table_name, stage_name)
#      13 def copy_data_to_table(cursor, table_name, stage_name):
#      14     copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
# ---> 15     cursor.execute(copy_command)
#
# ...

# %%
import snowflake.connector

def connect_to_snowflake(params):
    return snowflake.connector.connect(**params)

def create_snowflake_stage(cursor, stage_name):
    cursor.execute('USE ROLE ACCOUNTADMIN')
    cursor.execute(f'CREATE OR REPLACE STAGE {stage_name}')

def put_csv_file_to_stage(cursor, csv_file_path, stage_name):
    cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

def create_table_if_not_exists(cursor, table_name):
    create_table_query = f'''
        CREATE TABLE IF NOT EXISTS ACME_ECOMMERCE.OPERATIONS.{table_name} (
            factory_id INT,
            location_id INT,
            size VARCHAR,
            number_of_employees INT,
            in_use BOOLEAN
        )
    '''
    cursor.execute(create_table_query)

def copy_data_to_table(cursor, table_name, stage_name):
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cursor.execute(copy_command)

def verify_data_loaded(cursor, table_name):
    cursor.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cursor.fetchone()
    print(one_row)

def drop_snowflake_stage(cursor, stage_name):
    cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

def close_connection(cursor, connection):
    cursor.close()
    connection.close()

if __name__ == "__main__":
    # Snowflake connection parameters
    snowflake_params = {
        'account': 'pajfrmr-fd96872',
        'user': 'ANALYTICS_USER',
        'password': 'Infosum8-8',
        'warehouse': 'compute_wh',
        'database': 'ACME_ECOMMERCE',
        'schema': 'operations'
    }

    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Snowflake connection
    conn = connect_to_snowflake(snowflake_params)
    cur = conn.cursor()

    try:
        create_snowflake_stage(cur, stage_name)
        create_table_if_not_exists(cur, table_name)
        put_csv_file_to_stage(cur, csv_file_path, stage_name)
        copy_data_to_table(cur, table_name, stage_name)
        verify_data_loaded(cur, table_name)
    finally:
        # Drop the stage
        # drop_snowflake_stage(cur, stage_name)

        # Close cursor and connection
        close_connection(cur, conn)
# Out:
# (1, 1, 'large', 200, True)

# %%
pip install toml
# Out:
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\luism\Desktop\data\github_repos\sliide\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import snowflake.connector
import toml

def load_credentials_from_file(credentials_path):
    with open(credentials_path, 'r') as file:
        credentials = toml.load(file)
    return credentials

def connect_to_snowflake(params):
    return snowflake.connector.connect(**params)

def create_snowflake_stage(cursor, stage_name):
    cursor.execute('USE ROLE ACCOUNTADMIN')
    cursor.execute(f'CREATE OR REPLACE STAGE {stage_name}')

def put_csv_file_to_stage(cursor, csv_file_path, stage_name):
    cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

def create_table_if_not_exists(cursor, table_name):
    create_table_query = f'''
        CREATE TABLE IF NOT EXISTS ACME_ECOMMERCE.OPERATIONS.{table_name} (
            factory_id INT,
            location_id INT,
            size VARCHAR,
            number_of_employees INT,
            in_use BOOLEAN
        )
    '''
    cursor.execute(create_table_query)

def copy_data_to_table(cursor, table_name, stage_name):
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cursor.execute(copy_command)

def verify_data_loaded(cursor, table_name):
    cursor.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cursor.fetchone()
    print(one_row)

def drop_snowflake_stage(cursor, stage_name):
    cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

def close_connection(cursor, connection):
    cursor.close()
    connection.close()

if __name__ == "__main__":
    # Snowflake connection parameters
  
 # Load credentials from the TOML file
    credentials_path = 'secrets.toml'
    snowflake_params = load_credentials_from_file(credentials_path)



    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Snowflake connection
    conn = connect_to_snowflake(snowflake_params)
    cur = conn.cursor()

    try:
        create_snowflake_stage(cur, stage_name)
        create_table_if_not_exists(cur, table_name)
        put_csv_file_to_stage(cur, csv_file_path, stage_name)
        copy_data_to_table(cur, table_name, stage_name)
        verify_data_loaded(cur, table_name)
    finally:
        # Drop the stage
        # drop_snowflake_stage(cur, stage_name)

        # Close cursor and connection
        close_connection(cur, conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[68], line 64
#      61 table_name = 'FACTORIES'
#      63 # Snowflake connection
# ---> 64 conn = connect_to_snowflake(snowflake_params)
#      65 cur = conn.cursor()
#      67 try:
#
# Cell In[68], line 10, in connect_to_snowflake(params)
#       9 def connect_to_snowflake(params):
# ---> 10     return snowflake.connector.connect(**params)
#
# File c:\Users\luism\Desktop\data\github_repos\sliide\venv\lib\site-packages\snowflake\connector\__init__.py:54, in Connect(**kwargs)
#      52 @wraps(SnowflakeConnection.__init__)
#      53 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 54     return SnowflakeConnection(**kwargs)
#
# ...

# %%
import snowflake.connector
import toml

def load_credentials_from_file(credentials_path):
    with open(credentials_path, 'r') as file:
        credentials = toml.load(file)
    return credentials

def connect_to_snowflake(params):
    return snowflake.connector.connect(**params)

def create_snowflake_stage(cursor, stage_name):
    cursor.execute('USE ROLE ACCOUNTADMIN')
    cursor.execute(f"CREATE OR REPLACE STAGE {stage_name}")

def put_csv_file_to_stage(cursor, csv_file_path, stage_name):
    cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

def create_table_if_not_exists(cursor, table_name):
    create_table_query = f'''
        CREATE TABLE IF NOT EXISTS ACME_ECOMMERCE.OPERATIONS.{table_name} (
            factory_id INT,
            location_id INT,
            size VARCHAR,
            number_of_employees INT,
            in_use BOOLEAN
        )
    '''
    cursor.execute(create_table_query)

def copy_data_to_table(cursor, table_name, stage_name):
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV SKIP_HEADER=1)'
    cursor.execute(copy_command)

def verify_data_loaded(cursor, table_name):
    cursor.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cursor.fetchone()
    print(one_row)

def drop_snowflake_stage(cursor, stage_name):
    cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

def close_connection(cursor, connection):
    cursor.close()
    connection.close()

if __name__ == "__main__":
    # Snowflake connection parameters
  
    # Load credentials from the TOML file
    credentials_path = 'secrets.toml'
    snowflake_params = load_credentials_from_file(credentials_path)

    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Snowflake connection
    conn = connect_to_snowflake(snowflake_params)
    cur = conn.cursor()

            try:
        create_snowflake_stage(cur, stage_name)
        create_table_if_not_exists(cur, table_name)
        put_csv_file_to_stage(cur, csv_file_path, stage_name)
# Out:
#   Cell In[66], line 69
#
#     ^
# SyntaxError: incomplete input

# %%
import snowflake.connector
import toml

# Load credentials from secrets.toml
with open('secrets.toml', 'r') as file:
    config = toml.load(file)['snowflake']

# Establish Snowflake connection
conn = snowflake.connector.connect(
    account=config['account'],
    user=config['user'],
    password=config['password'],
    warehouse=config['warehouse'],
    database=config['database'],
    schema=config['schema']
)

cur = conn.cursor()

try:
    cur.execute('USE ROLE ACCOUNTADMIN')
    cur.execute('SELECT * FROM ACME_ECOMMERCE.OPERATIONS.FACTORIES')
    one_row = cur.fetchone()
    print(one_row)
finally:
    cur.close()
    conn.close()
# Out:
# (1, 1, 'large', 200, True)

# %%
import snowflake.connector
import toml

# Load credentials from secrets.toml
with open('secrets.toml', 'r') as file:
    config = toml.load(file)['snowflake']

# Establish Snowflake connection
conn = snowflake.connector.connect(
    account=config['account'],
    user=config['user'],
    password=config['password'],
    warehouse=config['warehouse'],
    database=config['database'],
    schema=config['schema']
)

def connect_to_snowflake(params):
    return snowflake.connector.connect(**params)

def create_snowflake_stage(cursor, stage_name):
    cursor.execute('USE ROLE ACCOUNTADMIN')
    cursor.execute(f'CREATE OR REPLACE STAGE {stage_name}')

def put_csv_file_to_stage(cursor, csv_file_path, stage_name):
    cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

def create_table_if_not_exists(cursor, table_name):
    create_table_query = f'''
        CREATE TABLE IF NOT EXISTS ACME_ECOMMERCE.OPERATIONS.{table_name} (
            factory_id INT,
            location_id INT,
            size VARCHAR,
            number_of_employees INT,
            in_use BOOLEAN
        )
    '''
    cursor.execute(create_table_query)

def copy_data_to_table(cursor, table_name, stage_name):
    copy_command = f'COPY INTO ACME_ECOMMERCE.OPERATIONS.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
    cursor.execute(copy_command)

def verify_data_loaded(cursor, table_name):
    cursor.execute(f'SELECT * FROM ACME_ECOMMERCE.OPERATIONS.{table_name}')
    one_row = cursor.fetchone()
    print(one_row)

def drop_snowflake_stage(cursor, stage_name):
    cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

def close_connection(cursor, connection):
    cursor.close()
    connection.close()

if __name__ == "__main__":
 

    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Snowflake connection
    
    cur = conn.cursor()

    try:
        create_snowflake_stage(cur, stage_name)
        create_table_if_not_exists(cur, table_name)
        put_csv_file_to_stage(cur, csv_file_path, stage_name)
        copy_data_to_table(cur, table_name, stage_name)
        verify_data_loaded(cur, table_name)
    finally:
        # Drop the stage
        # drop_snowflake_stage(cur, stage_name)

        # Close cursor and connection
        close_connection(cur, conn)
# Out:
# (1, 1, 'large', 200, True)

# %%
import snowflake.connector
import toml

class SnowflakeManager:
    def __init__(self, config_file='secrets.toml'):
        self.config = self.load_credentials(config_file)
        self.conn = self.establish_connection()

    def load_credentials(self, file_path):
        with open(file_path, 'r') as file:
            return toml.load(file)['snowflake']

    def establish_connection(self):
        return snowflake.connector.connect(
            account=self.config['account'],
            user=self.config['user'],
            password=self.config['password'],
            warehouse=self.config['warehouse'],
            database=self.config['database'],
            schema=self.config['schema']
        )

    def connect_to_snowflake(self, params):
        return snowflake.connector.connect(**params)

    def close_connection(self, cursor):
        cursor.close()
        self.conn.close()

class SnowflakeDataLoader:
    def __init__(self, cursor):
        self.cursor = cursor

    def create_snowflake_stage(self, stage_name):
        self.cursor.execute('USE ROLE ACCOUNTADMIN')
        self.cursor.execute(f'CREATE OR REPLACE STAGE {stage_name}')

    def put_csv_file_to_stage(self, csv_file_path, stage_name):
        self.cursor.execute(f"PUT file://{csv_file_path} @{stage_name}")

    def create_table_if_not_exists(self, table_name):
        create_table_query = f'''
            CREATE TABLE IF NOT EXISTS {database}.{schema}.{table_name} (
                factory_id INT,
                location_id INT,
                size VARCHAR,
                number_of_employees INT,
                in_use BOOLEAN
            )
        '''
        self.cursor.execute(create_table_query)

    def copy_data_to_table(self, table_name, stage_name):
        copy_command = f'COPY INTO {database}.{schema}.{table_name} FROM @{stage_name}/factories.csv FILE_FORMAT=(TYPE=CSV FIELD_OPTIONALLY_ENCLOSED_BY=\'"\' SKIP_HEADER=1)'
        self.cursor.execute(copy_command)

    def verify_data_loaded(self, table_name):
        self.cursor.execute(f'SELECT * FROM {database}.{schema}.{table_name}')
        one_row = self.cursor.fetchone()
        print(one_row)

    def drop_snowflake_stage(self, stage_name):
        self.cursor.execute(f'DROP STAGE IF EXISTS {stage_name}')

if __name__ == "__main__":
    # Snowflake stage information
    stage_name = 'MY_LOCAL_STAGE'

    # CSV file information
    csv_file_path = 'C:\\Users\\luism\\Desktop\\data\\github_repos\\sliide\\data\\pipeline_data\\factories.csv'
    table_name = 'FACTORIES'

    # Initialize SnowflakeManager and SnowflakeDataLoader
    snowflake_manager = SnowflakeManager()
    cursor = snowflake_manager.conn.cursor()
    data_loader = SnowflakeDataLoader(cursor)

    try:
        data_loader.create_snowflake_stage(stage_name)
        data_loader.create_table_if_not_exists(table_name)
        data_loader.put_csv_file_to_stage(csv_file_path, stage_name)
        data_loader.copy_data_to_table(table_name, stage_name)
        data_loader.verify_data_loaded(table_name)
    finally:
        # Uncomment the line below to drop the stage
        # data_loader.drop_snowflake_stage(stage_name)

        # Close cursor and connection
        snowflake_manager.close_connection(cursor)
# Out:
# (1, 1, 'large', 200, True)
